# %%
# Importing Library
import pandas as pd
import numpy as np

# %%
# Pandas Version
pd.__version__
# Out:
# '1.2.4'

# %% [markdown]
# ## What am i covering this course?
#         Advanced indexing with binary ops.
#         Sorting, lookups, and reording
#         Pruning duplicates, NAs, columns, rows+reindexing
#         Custome transformations: same-shape && agg
#         Advanced points on views, copies and memory.

# %% [markdown]
# #### NEW DATA
#         -- English Premier League Soccer Players
#         -- 400+ Players * 17 Attributes

# %%
data_url='https://andybek.com/pandas-soccer'

# %%
player=pd.read_csv(data_url)

# %%
player.head()
# Out:
#                 name     club  age position  position_cat  market_value  \
# 0     Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1         Mesut Ozil  Arsenal   28       AM             1          50.0
# 2          Petr Cech  Arsenal   35       GK             4           7.0
# 3       Theo Walcott  Arsenal   28       RW             1          20.0
# 4  Laurent Koscielny  Arsenal   31       CB             3          22.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# 1        4395        9.5   5.60%         167       2         Germany
# 2        1529        5.5   5.90%         134       2  Czech Republic
# 3        2393        7.5   1.50%         122       1         England
# 4         912        6.0   0.70%         121       2          France
#
#    new_foreign  age_cat  club_id  big_club  new_signing
# 0            0        4        1         1            0
# ...

# %%
# Data Information
player.info(memory_usage='deep',verbose=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 465 entries, 0 to 464
# Columns: 17 entries, name to new_signing
# dtypes: float64(2), int64(10), object(5)
# memory usage: 190.7 KB

# %%
# Data Type of player data list
player.dtypes.value_counts()
# Out:
# int64      10
# object      5
# float64     2
# dtype: int64

# %% [markdown]
# ### Indexing With Boolean Mask

# %%
player.head()
# Out:
#                 name     club  age position  position_cat  market_value  \
# 0     Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1         Mesut Ozil  Arsenal   28       AM             1          50.0
# 2          Petr Cech  Arsenal   35       GK             4           7.0
# 3       Theo Walcott  Arsenal   28       RW             1          20.0
# 4  Laurent Koscielny  Arsenal   31       CB             3          22.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# 1        4395        9.5   5.60%         167       2         Germany
# 2        1529        5.5   5.90%         134       2  Czech Republic
# 3        2393        7.5   1.50%         122       1         England
# 4         912        6.0   0.70%         121       2          France
#
#    new_foreign  age_cat  club_id  big_club  new_signing
# 0            0        4        1         1            0
# ...

# %%
player.position.unique().size
# Out:
# 14

# %%
# Defender Codes: LB, CB, RB
# Extracting Data From position by the condition like isin(if it is available to this dataset)
player.position.isin(['LB','CB','RB'])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 460    False
# 461     True
# 462     True
# 463    False
# 464    False
# Name: position, Length: 465, dtype: bool

# %%
player[player.position.isin(['LB','CB','RB'])].head()
# Out:
#                  name     club  age position  position_cat  market_value  \
# 4   Laurent Koscielny  Arsenal   31       CB             3          22.0
# 5     Hector Bellerin  Arsenal   22       RB             3          30.0
# 7       Nacho Monreal  Arsenal   31       LB             3          13.0
# 8    Shkodran Mustafi  Arsenal   25       CB             3          30.0
# 17   Gabriel Paulista  Arsenal   26       CB             3          13.0
#
#     page_views  fpl_value fpl_sel  fpl_points  region nationality  \
# 4          912        6.0   0.70%         121       2      France
# 5         1675        6.0  13.70%         119       2       Spain
# 7          555        5.5   4.70%         115       2       Spain
# 8         1877        5.5   4.00%          90       2     Germany
# 17         552        5.0   0.10%          45       3      Brazil
#
#     new_foreign  age_cat  club_id  big_club  new_signing
# 4             0        4        1         1            0
# ...

# %%
player[player.position.isin(['LB','CB','RB'])]
# Out:
#                   name      club  age position  position_cat  market_value  \
# 4    Laurent Koscielny   Arsenal   31       CB             3          22.0
# 5      Hector Bellerin   Arsenal   22       RB             3          30.0
# 7        Nacho Monreal   Arsenal   31       LB             3          13.0
# 8     Shkodran Mustafi   Arsenal   25       CB             3          30.0
# 17    Gabriel Paulista   Arsenal   26       CB             3          13.0
# ..                 ...       ...  ...      ...           ...           ...
# 455    Aaron Cresswell  West+Ham   27       LB             3          12.0
# 458     Angelo Ogbonna  West+Ham   29       CB             3           9.0
# 459     Pablo Zabaleta  West+Ham   32       RB             3           7.0
# 461     Arthur Masuaku  West+Ham   23       LB             3           7.0
# 462          Sam Byram  West+Ham   23       RB             3           4.5
#
# ...

# %%
# Extracting data by range into indicate value
# inclusive=False==> 40 and 50 are not include
player[player.market_value.between(40,50, inclusive=False)]
# Out:
#                   name             club  age position  position_cat  \
# 218  Philippe Coutinho        Liverpool   25       AM             1
# 246    Raheem Sterling  Manchester+City   22       LW             1
# 380          Dele Alli        Tottenham   21       CM             2
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 218          45.0        2958        9.0  30.80%         171       3
# 246          45.0        2074        8.0   3.80%         149       1
# 380          45.0        4626        9.5  38.60%         225       1
#
#     nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 218      Brazil            0        3       10         1            0
# 246     England            0        2       11         1            0
# 380     England            0        1       17         1            0

# %%
player.age <= 25
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 460     True
# 461     True
# 462     True
# 463     True
# 464    False
# Name: age, Length: 465, dtype: bool

# %%
# Less than equal 25
player[player.age <= 25]
# Out:
#                     name      club  age position  position_cat  market_value  \
# 5        Hector Bellerin   Arsenal   22       RB             3          30.0
# 8       Shkodran Mustafi   Arsenal   25       CB             3          30.0
# 9             Alex Iwobi   Arsenal   21       LW             1          10.0
# 10          Granit Xhaka   Arsenal   24       DM             2          35.0
# 11          Granit Xhaka   Arsenal   24       DM             2          35.0
# ..                   ...       ...  ...      ...           ...           ...
# 456         Pedro Obiang  West+Ham   25       CM             2           9.0
# 460  Edimilson Fernandes  West+Ham   21       CM             2           5.0
# 461       Arthur Masuaku  West+Ham   23       LB             3           7.0
# 462            Sam Byram  West+Ham   23       RB             3           4.5
# 463      Ashley Fletcher  West+Ham   21       CF             1           1.0
#
# ...

# %%
# Less than equal 25 with Pandas way
player[player.age.le(25)]
# Out:
#                     name      club  age position  position_cat  market_value  \
# 5        Hector Bellerin   Arsenal   22       RB             3          30.0
# 8       Shkodran Mustafi   Arsenal   25       CB             3          30.0
# 9             Alex Iwobi   Arsenal   21       LW             1          10.0
# 10          Granit Xhaka   Arsenal   24       DM             2          35.0
# 11          Granit Xhaka   Arsenal   24       DM             2          35.0
# ..                   ...       ...  ...      ...           ...           ...
# 456         Pedro Obiang  West+Ham   25       CM             2           9.0
# 460  Edimilson Fernandes  West+Ham   21       CM             2           5.0
# 461       Arthur Masuaku  West+Ham   23       LB             3           7.0
# 462            Sam Byram  West+Ham   23       RB             3           4.5
# 463      Ashley Fletcher  West+Ham   21       CF             1           1.0
#
# ...

# %% [markdown]
# ## Comparators
#     Comparision Operator   Pandas Method
#
#         <    ---------------    .lt()    Support
#         <=   ---------------    .le()   Fill_value
#         >    ---------------    .gt()
#         >=   ---------------    .ge()
#         ==   ---------------    .eq()

# %%
# Less than
# player[player.age < 25]
player[player.age.lt(25)]
# Out:
#                         name      club  age position  position_cat  \
# 5            Hector Bellerin   Arsenal   22       RB             3
# 9                 Alex Iwobi   Arsenal   21       LW             1
# 10              Granit Xhaka   Arsenal   24       DM             2
# 11              Granit Xhaka   Arsenal   24       DM             2
# 12   Alex Oxlade-Chamberlain   Arsenal   23       RM             2
# ..                       ...       ...  ...      ...           ...
# 444           Manuel Lanzini  West+Ham   24       AM             1
# 460      Edimilson Fernandes  West+Ham   21       CM             2
# 461           Arthur Masuaku  West+Ham   23       LB             3
# 462                Sam Byram  West+Ham   23       RB             3
# 463          Ashley Fletcher  West+Ham   21       CF             1
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 5            30.0        1675        6.0  13.70%         119       2
# ...

# %%
# Less than equal
# player[player.age <= 25]
player[player.age.le(25)]
# Out:
#                     name      club  age position  position_cat  market_value  \
# 5        Hector Bellerin   Arsenal   22       RB             3          30.0
# 8       Shkodran Mustafi   Arsenal   25       CB             3          30.0
# 9             Alex Iwobi   Arsenal   21       LW             1          10.0
# 10          Granit Xhaka   Arsenal   24       DM             2          35.0
# 11          Granit Xhaka   Arsenal   24       DM             2          35.0
# ..                   ...       ...  ...      ...           ...           ...
# 456         Pedro Obiang  West+Ham   25       CM             2           9.0
# 460  Edimilson Fernandes  West+Ham   21       CM             2           5.0
# 461       Arthur Masuaku  West+Ham   23       LB             3           7.0
# 462            Sam Byram  West+Ham   23       RB             3           4.5
# 463      Ashley Fletcher  West+Ham   21       CF             1           1.0
#
# ...

# %%
# Greater than
# player[player.age > 25]
player[player.age.gt(25)]
# Out:
#                   name      club  age position  position_cat  market_value  \
# 0       Alexis Sanchez   Arsenal   28       LW             1          65.0
# 1           Mesut Ozil   Arsenal   28       AM             1          50.0
# 2            Petr Cech   Arsenal   35       GK             4           7.0
# 3         Theo Walcott   Arsenal   28       RW             1          20.0
# 4    Laurent Koscielny   Arsenal   31       CB             3          22.0
# ..                 ...       ...  ...      ...           ...           ...
# 455    Aaron Cresswell  West+Ham   27       LB             3          12.0
# 457   Sofiane Feghouli  West+Ham   27       RW             1          12.0
# 458     Angelo Ogbonna  West+Ham   29       CB             3           9.0
# 459     Pablo Zabaleta  West+Ham   32       RB             3           7.0
# 464       Diafra Sakho  West+Ham   27       CF             1          10.0
#
# ...

# %%
# Greater than equal
# player[player.age >= 25]
player[player.age.ge(25)]
# Out:
#                   name      club  age position  position_cat  market_value  \
# 0       Alexis Sanchez   Arsenal   28       LW             1          65.0
# 1           Mesut Ozil   Arsenal   28       AM             1          50.0
# 2            Petr Cech   Arsenal   35       GK             4           7.0
# 3         Theo Walcott   Arsenal   28       RW             1          20.0
# 4    Laurent Koscielny   Arsenal   31       CB             3          22.0
# ..                 ...       ...  ...      ...           ...           ...
# 456       Pedro Obiang  West+Ham   25       CM             2           9.0
# 457   Sofiane Feghouli  West+Ham   27       RW             1          12.0
# 458     Angelo Ogbonna  West+Ham   29       CB             3           9.0
# 459     Pablo Zabaleta  West+Ham   32       RB             3           7.0
# 464       Diafra Sakho  West+Ham   27       CF             1          10.0
#
# ...

# %%
# equal
# player[player.age == 25]
player[player.age.eq(25)].head(5)
# Out:
#                 name         club  age position  position_cat  market_value  \
# 8   Shkodran Mustafi      Arsenal   25       CB             3          30.0
# 14     Jack Wilshere      Arsenal   25       CM             2          18.0
# 22    Mohamed Elneny      Arsenal   25       DM             2          10.0
# 27    Carl Jenkinson      Arsenal   25       RB             3           5.0
# 32       Joshua King  Bournemouth   25       SS             1           8.0
#
#     page_views  fpl_value fpl_sel  fpl_points  region nationality  \
# 8         1877        5.5   4.00%          90       2     Germany
# 14        1759        5.5   0.00%          61       1     England
# 22         683        4.5   0.80%          26       4       Egypt
# 27         561        4.5   0.40%           2       1     England
# 32         997        7.5  10.40%         178       2      Norway
#
#     new_foreign  age_cat  club_id  big_club  new_signing
# ...

# %% [markdown]
# ### Binary (or Bitwise) Operators With Boolean
#
#     Operator      What Is     Example
#     |               OR        True | False ==> True
#     &               AND       True & False ==> False
#     ^               XOR       True ^ False ==> True
#     !             Complement  ~True ==> -2

# %% [markdown]
# #### OR Operator

# %%
True | True
# Out:
# True

# %%
True | False
# Out:
# True

# %%
False | True
# Out:
# True

# %%
True | True
# Out:
# True

# %% [markdown]
# #### AND Operator

# %%
False & False
# Out:
# False

# %%
False & True
# Out:
# False

# %%
True & False
# Out:
# False

# %%
True & True
# Out:
# True

# %%
# Single False is enough! 
True & True & False & True
# Out:
# False

# %%
f=pd.Series(False)
f
# Out:
# 0    False
# dtype: bool

# %%
t=pd.Series(True)
t
# Out:
# 0    True
# dtype: bool

# %%
# Binary Operator through AND
f & t
# Out:
# 0    False
# dtype: bool

# %%
# OR binary operator
f | t
# Out:
# 0    True
# dtype: bool

# %%
t=pd.Series(True if i%2==0 else False for i in range(10))
t
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4     True
# 5    False
# 6     True
# 7    False
# 8     True
# 9    False
# dtype: bool

# %%
f=pd.Series(False for i in range(10))
f
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# dtype: bool

# %%
# OR binary operator
f | t
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4     True
# 5    False
# 6     True
# 7    False
# 8     True
# 9    False
# dtype: bool

# %%
# AND binary operator
f & t
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# dtype: bool

# %% [markdown]
# ### When combine two pandas series ,combination is done label to label not based on the order

# %%
f=pd.Series(data=[False,True, True], index=['c','b','a'])

# %%
t=pd.Series(data=[True, False,False], index=['a','b','c'])

# %%
f & t
# Out:
# a     True
# b    False
# c    False
# dtype: bool

# %% [markdown]
# #### XOR Binary Operator --> ^

# %%
False ^ True
# Out:
# True

# %%
False ^ False
# Out:
# False

# %%
True ^ False
# Out:
# True

# %%
True ^ True
# Out:
# False

# %%
True ^ (False | False & True) | False
# Out:
# True

# %% [markdown]
# #### (Two's) Complement -->  ~
#
#      BITS                       INTEGER
#      00000000                       0
#      00000001                       1
#      00000010                       2   ^ Inverts the bits(e.=> ~1 = -2)
#
#      11111111                       -1
#      11111110                       -2
#      11111101                       -3

# %%
~False
# Out:
# -1

# %%
~True
# Out:
# -2

# %% [markdown]
# ## A Number Format:
#        --- A system for representing signed integers in compuetrs.Using x bit we could represent 2^x numbers
#        --- For Example: 32 bits represent 4294967296, 64 bits 18446755073709551616, and so on.
#
#        BITS                       INTEGER
#      00000000                       0
#      00000001                       1
#      00000010                       2
#
#      11111111                       -1
#      11111110                       -2
#      11111101                       -3

# %%
~1
# Out:
# -2

# %%
t
# Out:
# a     True
# b    False
# c    False
# dtype: bool

# %%
~t
# Out:
# a    False
# b     True
# c     True
# dtype: bool

# %% [markdown]
# ### Combining Condition

# %%
# select all the left backs who are 25 or younger
player[
    (player.position == 'LB') & 
    (player.age <= 25)
]
# Out:
#                  name               club  age position  position_cat  \
# 29     Sead Kolasinac            Arsenal   24       LB             3
# 54         Brad Smith        Bournemouth   23       LB             3
# 112            Kenedy            Chelsea   21       LB             3
# 128   Jeffrey Schlupp     Crystal+Palace   24       LB             3
# 212      Ben Chilwell     Leicester+City   20       LB             3
# 236    Alberto Moreno          Liverpool   25       LB             3
# 281         Luke Shaw  Manchester+United   22       LB             3
# 294      Paul Dummett   Newcastle+United   25       LB             3
# 298  Massadio Haidara   Newcastle+United   24       LB             3
# 328      Matt Targett        Southampton   21       LB             3
# 354        Josh Tymon         Stoke+City   18       LB             3
# 369  Stephen Kingsley            Swansea   22       LB             3
# 389        Ben Davies          Tottenham   24       LB             3
# ...

# %%
# select all the left backs who are 25 or younger and market value 10+
player[
    (player.position == 'LB') & 
    (player.age <= 25) &
    (player.market_value >= 10)
]
# Out:
#                name               club  age position  position_cat  \
# 29   Sead Kolasinac            Arsenal   24       LB             3
# 236  Alberto Moreno          Liverpool   25       LB             3
# 281       Luke Shaw  Manchester+United   22       LB             3
# 389      Ben Davies          Tottenham   24       LB             3
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 29           15.0         618        6.0   6.90%           0       2
# 236          10.0         397        4.5   0.30%           8       2
# 281          20.0         947        5.0   0.40%          45       1
# 389          12.0         396        5.5   1.80%          90       2
#
#     nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 29       Bosnia            1        2        1         1            0
# 236       Spain            0        3       10         1            0
# 281     England            0        2       12         1            0
# ...

# %%
# select all the left backs who are 25 or younger and market value 10+ Not from Arsenal and Tottenham
player[
    (player.position == 'LB') & 
    (player.age <= 25) &
    (player.market_value >= 10) &
    ~(player.club.isin(['Arsenal','Tottenham']))
]
# Out:
#                name               club  age position  position_cat  \
# 236  Alberto Moreno          Liverpool   25       LB             3
# 281       Luke Shaw  Manchester+United   22       LB             3
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 236          10.0         397        4.5   0.30%           8       2
# 281          20.0         947        5.0   0.40%          45       1
#
#     nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 236       Spain            0        3       10         1            0
# 281     England            0        2       12         1            0

# %% [markdown]
# #### Condition As Variable

# %%
# Arsenal right backs and Chelses goalkeepers
arsenal_player=(player.club.eq('Arsenal'))

# %%
arsenal_right_back=(player.position.eq('RB'))

# %%
c_and_GK= (player.club.eq('Chelsea')) & (player.position.eq('GK'))

# %%
player.loc[arsenal_player & arsenal_right_back | c_and_GK]
# Out:
#                  name     club  age position  position_cat  market_value  \
# 5     Hector Bellerin  Arsenal   22       RB             3          30.0
# 27     Carl Jenkinson  Arsenal   25       RB             3           5.0
# 102  Thibaut Courtois  Chelsea   25       GK             4          40.0
# 109   Willy Caballero  Chelsea   35       GK             4           1.5
#
#      page_views  fpl_value fpl_sel  fpl_points  region nationality  \
# 5          1675        6.0  13.70%         119       2       Spain
# 27          561        4.5   0.40%           2       1     England
# 102        1260        5.5  18.50%         141       2     Belgium
# 109         542        5.0   0.20%          64       3   Argentina
#
#      new_foreign  age_cat  club_id  big_club  new_signing
# 5              0        2        1         1            0
# 27             0        3        1         1            0
# 102            0        3        5         1            0
# ...

# %% [markdown]
# #### Skill Challenge
#     1.They are English(nationality) and
#     2.Their market value is more than twice the average market value in the league and
#     3.They either have more than 4000 views or are a new signning but not both

# %%
player.head()
# Out:
#                 name     club  age position  position_cat  market_value  \
# 0     Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1         Mesut Ozil  Arsenal   28       AM             1          50.0
# 2          Petr Cech  Arsenal   35       GK             4           7.0
# 3       Theo Walcott  Arsenal   28       RW             1          20.0
# 4  Laurent Koscielny  Arsenal   31       CB             3          22.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# 1        4395        9.5   5.60%         167       2         Germany
# 2        1529        5.5   5.90%         134       2  Czech Republic
# 3        2393        7.5   1.50%         122       1         England
# 4         912        6.0   0.70%         121       2          France
#
#    new_foreign  age_cat  club_id  big_club  new_signing
# 0            0        4        1         1            0
# ...

# %%
# First Condition
player_nation=player.nationality.eq('England')

# %%
# Second Condition
market_value=player.market_value > player.market_value.mean() * 2

# %%
# Third Condition
pop_and_ns=(player.page_views > 4000) ^ (player.new_signing == 1)

# %%
player[player_nation & market_value & pop_and_ns]
# Out:
#             name             club  age position  position_cat  market_value  \
# 256  John Stones  Manchester+City   23       CB             3          35.0
# 380    Dele Alli        Tottenham   21       CM             2          45.0
# 381   Harry Kane        Tottenham   23       CF             1          60.0
#
#      page_views  fpl_value fpl_sel  fpl_points  region nationality  \
# 256        1078        5.5   2.30%          59       1     England
# 380        4626        9.5  38.60%         225       1     England
# 381        4161       12.5  35.10%         224       1     England
#
#      new_foreign  age_cat  club_id  big_club  new_signing
# 256            0        2       11         1            1
# 380            0        1       17         1            0
# 381            0        2       17         1            0

# %% [markdown]
# ### 2D indexing

# %%
# Chelsea player and 23 years or yooungers
chelsea_player = (player.club == 'Chelsea') & (player.age.le(23))

# %%
player[chelsea_player]
# Out:
#                  name     club  age position  position_cat  market_value  \
# 110   Michy Batshuayi  Chelsea   23       CF             1          25.0
# 111        Kurt Zouma  Chelsea   22       CB             3          15.0
# 112            Kenedy  Chelsea   21       LB             3           7.0
# 115  Tiemoue Bakayoko  Chelsea   22       DM             2          16.0
#
#      page_views  fpl_value fpl_sel  fpl_points  region nationality  \
# 110        1162        8.5   1.60%          48       2     Belgium
# 111         723        5.5   0.80%          15       2      France
# 112         566        5.0   0.10%           3       3      Brazil
# 115        1011        5.0   1.60%           0       2      France
#
#      new_foreign  age_cat  club_id  big_club  new_signing
# 110            0        2        5         1            1
# 111            0        2        5         1            0
# 112            0        1        5         1            0
# ...

# %%
# Specific way to extract by condition and columns position
player.loc[chelsea_player,['name', 'club', 'market_value']]
# Out:
#                  name     club  market_value
# 110   Michy Batshuayi  Chelsea          25.0
# 111        Kurt Zouma  Chelsea          15.0
# 112            Kenedy  Chelsea           7.0
# 115  Tiemoue Bakayoko  Chelsea          16.0

# %%
player.loc[chelsea_player,['name', 'club', 'market_value']]
# Out:
#                  name     club  market_value
# 110   Michy Batshuayi  Chelsea          25.0
# 111        Kurt Zouma  Chelsea          15.0
# 112            Kenedy  Chelsea           7.0
# 115  Tiemoue Bakayoko  Chelsea          16.0

# %%
# Select all column the begin with 'p'
start_with_p=player.columns.str.startswith('p')
start_with_p
# Out:
# array([False, False, False,  True,  True, False,  True, False, False,
#        False, False, False, False, False, False, False, False])

# %%
play_loc=player.loc[chelsea_player,start_with_p]
play_loc
# Out:
#     position  position_cat  page_views
# 110       CF             1        1162
# 111       CB             3         723
# 112       LB             3         566
# 115       DM             2        1011

# %%
print(start_with_p.shape)
# Out:
# (17,)

# %%
print(play_loc.shape)
# Out:
# (4, 3)

# %%
# Chaining
player[chelsea_player]['position']
# Out:
# 110    CF
# 111    CB
# 112    LB
# 115    DM
# Name: position, dtype: object

# %%
# Recommanded Teq
player.loc[chelsea_player,['position']]
# Out:
#     position
# 110       CF
# 111       CB
# 112       LB
# 115       DM

# %% [markdown]
# #### Selection Terminology Recap
#
#         OPERATOR                                         WHAT IS
#    1.player.loc[0:2]=====================================slicing
#    2.player.loc[player.age > 37]======================Boolean Masking
#    3.player.loc[132, 'name']=======================Basic (label-based) indexing
#    4.player.loc[[0, 132], ['name','market_value']]=======fancy indexing
#    5.player.lookup([0, 132], ['name','market_value'])====fancy indexing

# %%
# fancy indexing
player.loc[[0,132],['name','market_value']]
# Out:
#                name  market_value
# 0    Alexis Sanchez          65.0
# 132  Connor Wickham           6.0

# %%
player.lookup([0,132],['name','market_value'])
# Out:
# <ipython-input-75-0a3fc1bde7cb>:1: FutureWarning: The 'lookup' method is deprecated and will beremoved in a future version.You can use DataFrame.melt and DataFrame.locas a substitute.
#   player.lookup([0,132],['name','market_value'])
# array(['Alexis Sanchez', 6.0], dtype=object)

# %%
player.lookup([0,132],['market_value','name'])
# Out:
# <ipython-input-76-eadc10941f75>:1: FutureWarning: The 'lookup' method is deprecated and will beremoved in a future version.You can use DataFrame.melt and DataFrame.locas a substitute.
#   player.lookup([0,132],['market_value','name'])
# array([65.0, 'Connor Wickham'], dtype=object)

# %% [markdown]
# #### Sorting By Index or Columns

# %%
player.head()
# Out:
#                 name     club  age position  position_cat  market_value  \
# 0     Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1         Mesut Ozil  Arsenal   28       AM             1          50.0
# 2          Petr Cech  Arsenal   35       GK             4           7.0
# 3       Theo Walcott  Arsenal   28       RW             1          20.0
# 4  Laurent Koscielny  Arsenal   31       CB             3          22.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# 1        4395        9.5   5.60%         167       2         Germany
# 2        1529        5.5   5.90%         134       2  Czech Republic
# 3        2393        7.5   1.50%         122       1         England
# 4         912        6.0   0.70%         121       2          France
#
#    new_foreign  age_cat  club_id  big_club  new_signing
# 0            0        4        1         1            0
# ...

# %%
player.sort_values(by='name',ascending=True)
# Out:
#                    name            club  age position  position_cat  \
# 455     Aaron Cresswell        West+Ham   27       LB             3
# 157        Aaron Lennon         Everton   30       RW             1
# 176          Aaron Mooy    Huddersfield   26       CM             2
# 15         Aaron Ramsey         Arsenal   26       CM             2
# 413  Abdoulaye Doucoure         Watford   24       CM             2
# ..                  ...             ...  ...      ...           ...
# 123        Yohan Cabaye  Crystal+Palace   31       CM             2
# 407      YounÃ¨s Kaboul         Watford   31       CB             3
# 400     Ã‰tienne Capoue         Watford   29       DM             2
# 370       Ã€ngel Rangel         Swansea   34       RB             3
# 357  Åukasz FabiaÅ„ski         Swansea   32       GK             4
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 455          12.0         380        5.0   1.30%          60       1
# ...

# %%
# Sorting Index by sort_index()
player.set_index('name').sort_index().head(3)
# Out:
#                          club  age position  position_cat  market_value  \
# name
# Aaron Cresswell      West+Ham   27       LB             3          12.0
# Aaron Lennon          Everton   30       RW             1           5.0
# Aaron Mooy       Huddersfield   26       CM             2           5.0
#
#                  page_views  fpl_value fpl_sel  fpl_points  region  \
# name
# Aaron Cresswell         380        5.0   1.30%          60       1
# Aaron Lennon            504        5.5   0.20%          22       1
# Aaron Mooy              588        5.5   2.50%           0       4
#
#                 nationality  new_foreign  age_cat  club_id  big_club  \
# name
# Aaron Cresswell     England            0        3       20         0
# Aaron Lennon        England            0        4        7         0
# Aaron Mooy        Australia            0        3        8         0
#
#                  new_signing
# name
# Aaron Cresswell            0
# Aaron Lennon               0
# ...

# %%
# Sorting Column axis by sort_index()
player.set_index('name').sort_index(axis=1)
# Out:
#                      age  age_cat  big_club      club  club_id  fpl_points  \
# name
# Alexis Sanchez        28        4         1   Arsenal        1         264
# Mesut Ozil            28        4         1   Arsenal        1         167
# Petr Cech             35        6         1   Arsenal        1         134
# Theo Walcott          28        4         1   Arsenal        1         122
# Laurent Koscielny     31        4         1   Arsenal        1         121
# ...                  ...      ...       ...       ...      ...         ...
# Edimilson Fernandes   21        1         0  West+Ham       20          38
# Arthur Masuaku        23        2         0  West+Ham       20          34
# Sam Byram             23        2         0  West+Ham       20          29
# Ashley Fletcher       21        1         0  West+Ham       20          16
# Diafra Sakho          27        3         0  West+Ham       20          12
#
# ...

# %%
# Sorting Index and Column axis by sort_index()
player.set_index('name').sort_index(axis=1).sort_index(axis=0).head()
# Out:
#                     age  age_cat  big_club          club  club_id  fpl_points  \
# name
# Aaron Cresswell      27        3         0      West+Ham       20          60
# Aaron Lennon         30        4         0       Everton        7          22
# Aaron Mooy           26        3         0  Huddersfield        8           0
# Aaron Ramsey         26        3         1       Arsenal        1          56
# Abdoulaye Doucoure   24        2         0       Watford       18          38
#
#                    fpl_sel  fpl_value  market_value nationality  new_foreign  \
# name
# Aaron Cresswell      1.30%        5.0          12.0     England            0
# Aaron Lennon         0.20%        5.5           5.0     England            0
# Aaron Mooy           2.50%        5.5           5.0   Australia            0
# Aaron Ramsey         5.10%        7.0          35.0       Wales            0
# Abdoulaye Doucoure   0.00%        5.0           6.0      France            0
#
# ...

# %%
player.sort_index(axis=0,inplace=True)

# %%
player.head()
# Out:
#                 name     club  age position  position_cat  market_value  \
# 0     Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1         Mesut Ozil  Arsenal   28       AM             1          50.0
# 2          Petr Cech  Arsenal   35       GK             4           7.0
# 3       Theo Walcott  Arsenal   28       RW             1          20.0
# 4  Laurent Koscielny  Arsenal   31       CB             3          22.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# 1        4395        9.5   5.60%         167       2         Germany
# 2        1529        5.5   5.90%         134       2  Czech Republic
# 3        2393        7.5   1.50%         122       1         England
# 4         912        6.0   0.70%         121       2          France
#
#    new_foreign  age_cat  club_id  big_club  new_signing
# 0            0        4        1         1            0
# ...

# %%
# Reset indexing by before soring index
player.reset_index()
# Out:
#      index                 name      club  age position  position_cat  \
# 0        0       Alexis Sanchez   Arsenal   28       LW             1
# 1        1           Mesut Ozil   Arsenal   28       AM             1
# 2        2            Petr Cech   Arsenal   35       GK             4
# 3        3         Theo Walcott   Arsenal   28       RW             1
# 4        4    Laurent Koscielny   Arsenal   31       CB             3
# ..     ...                  ...       ...  ...      ...           ...
# 460    460  Edimilson Fernandes  West+Ham   21       CM             2
# 461    461       Arthur Masuaku  West+Ham   23       LB             3
# 462    462            Sam Byram  West+Ham   23       RB             3
# 463    463      Ashley Fletcher  West+Ham   21       CF             1
# 464    464         Diafra Sakho  West+Ham   27       CF             1
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# ...

# %%
# player.reset_index().reset_index().reset_index()
player.reset_index(inplace=True)

# %%
player.head()
# Out:
#    index               name     club  age position  position_cat  \
# 0      0     Alexis Sanchez  Arsenal   28       LW             1
# 1      1         Mesut Ozil  Arsenal   28       AM             1
# 2      2          Petr Cech  Arsenal   35       GK             4
# 3      3       Theo Walcott  Arsenal   28       RW             1
# 4      4  Laurent Koscielny  Arsenal   31       CB             3
#
#    market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 0          65.0        4329       12.0  17.10%         264       3
# 1          50.0        4395        9.5   5.60%         167       2
# 2           7.0        1529        5.5   5.90%         134       2
# 3          20.0        2393        7.5   1.50%         122       1
# 4          22.0         912        6.0   0.70%         121       2
#
#       nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 0           Chile            0        4        1         1            0
# ...

# %% [markdown]
# ### Sorting or Reordering

# %%
# Comfortable way to sort by reindex()
players=player.iloc[:4,:4]

# %%
players
# Out:
#    index            name     club  age
# 0      0  Alexis Sanchez  Arsenal   28
# 1      1      Mesut Ozil  Arsenal   28
# 2      2       Petr Cech  Arsenal   35
# 3      3    Theo Walcott  Arsenal   28

# %%
# Row order: 3,2,1,0
# Column order: age, name, position, market_value
players.reindex(index=[3,2,1,0],columns=['age', 'name', 'position', 'market_value'])
# Out:
#    age            name  position  market_value
# 3   28    Theo Walcott       NaN           NaN
# 2   35       Petr Cech       NaN           NaN
# 1   28      Mesut Ozil       NaN           NaN
# 0   28  Alexis Sanchez       NaN           NaN

# %%
# You can directly apply main dataset
player.reindex(index=[3,2,1,0],columns=['age', 'name', 'position', 'market_value'])
# Out:
#    age            name position  market_value
# 3   28    Theo Walcott       RW          20.0
# 2   35       Petr Cech       GK           7.0
# 1   28      Mesut Ozil       AM          50.0
# 0   28  Alexis Sanchez       LW          65.0

# %%
# iterable
iter(player.columns)

# %%
# Boolean are not iterable
# iter(True)

# %%
# get all the columns and have the alphabetical order
player.reindex(index=[3,4,2,1,0],columns=sorted(player.columns))
# Out:
#    age  age_cat  big_club     club  club_id  fpl_points fpl_sel  fpl_value  \
# 3   28        4         1  Arsenal        1         122   1.50%        7.5
# 4   31        4         1  Arsenal        1         121   0.70%        6.0
# 2   35        6         1  Arsenal        1         134   5.90%        5.5
# 1   28        4         1  Arsenal        1         167   5.60%        9.5
# 0   28        4         1  Arsenal        1         264  17.10%       12.0
#
#    index  market_value               name     nationality  new_foreign  \
# 3      3          20.0       Theo Walcott         England            0
# 4      4          22.0  Laurent Koscielny          France            0
# 2      2           7.0          Petr Cech  Czech Republic            0
# 1      1          50.0         Mesut Ozil         Germany            0
# 0      0          65.0     Alexis Sanchez           Chile            0
#
#    new_signing  page_views position  position_cat  region
# ...

# %%
player.reindex(index=[3,4,2,1,0]).sort_index(axis=1)
# Out:
#    age  age_cat  big_club     club  club_id  fpl_points fpl_sel  fpl_value  \
# 3   28        4         1  Arsenal        1         122   1.50%        7.5
# 4   31        4         1  Arsenal        1         121   0.70%        6.0
# 2   35        6         1  Arsenal        1         134   5.90%        5.5
# 1   28        4         1  Arsenal        1         167   5.60%        9.5
# 0   28        4         1  Arsenal        1         264  17.10%       12.0
#
#    index  market_value               name     nationality  new_foreign  \
# 3      3          20.0       Theo Walcott         England            0
# 4      4          22.0  Laurent Koscielny          France            0
# 2      2           7.0          Petr Cech  Czech Republic            0
# 1      1          50.0         Mesut Ozil         Germany            0
# 0      0          65.0     Alexis Sanchez           Chile            0
#
#    new_signing  page_views position  position_cat  region
# ...

# %% [markdown]
# #### Another way

# %%
player.columns
# Out:
# Index(['index', 'name', 'club', 'age', 'position', 'position_cat',
#        'market_value', 'page_views', 'fpl_value', 'fpl_sel', 'fpl_points',
#        'region', 'nationality', 'new_foreign', 'age_cat', 'club_id',
#        'big_club', 'new_signing'],
#       dtype='object')

# %%
sorted(player.columns)
# Out:
# ['age',
#  'age_cat',
#  'big_club',
#  'club',
#  'club_id',
#  'fpl_points',
#  'fpl_sel',
#  'fpl_value',
#  'index',
#  'market_value',
#  'name',
#  'nationality',
#  'new_foreign',
#  'new_signing',
#  'page_views',
#  'position',
#  'position_cat',
#  'region']

# %%
# Beacuse columns support arry like object
player.reindex(index=[1,3,5,7,0],columns=player.columns.sort_values())
# Out:
#    age  age_cat  big_club     club  club_id  fpl_points fpl_sel  fpl_value  \
# 1   28        4         1  Arsenal        1         167   5.60%        9.5
# 3   28        4         1  Arsenal        1         122   1.50%        7.5
# 5   22        2         1  Arsenal        1         119  13.70%        6.0
# 7   31        4         1  Arsenal        1         115   4.70%        5.5
# 0   28        4         1  Arsenal        1         264  17.10%       12.0
#
#    index  market_value             name nationality  new_foreign  new_signing  \
# 1      1          50.0       Mesut Ozil     Germany            0            0
# 3      3          20.0     Theo Walcott     England            0            0
# 5      5          30.0  Hector Bellerin       Spain            0            0
# 7      7          13.0    Nacho Monreal       Spain            0            0
# 0      0          65.0   Alexis Sanchez       Chile            0            0
#
#    page_views position  position_cat  region
# ...

# %% [markdown]
# #### Avoiding Sorting like this way

# %%
players
# Out:
#    index            name     club  age
# 0      0  Alexis Sanchez  Arsenal   28
# 1      1      Mesut Ozil  Arsenal   28
# 2      2       Petr Cech  Arsenal   35
# 3      3    Theo Walcott  Arsenal   28

# %%
players.swapaxes(1,0)
# Out:
#                     0           1          2             3
# index               0           1          2             3
# name   Alexis Sanchez  Mesut Ozil  Petr Cech  Theo Walcott
# club          Arsenal     Arsenal    Arsenal       Arsenal
# age                28          28         35            28

# %%
players.T.sort_index().T
# Out:
#   age     club index            name
# 0  28  Arsenal     0  Alexis Sanchez
# 1  28  Arsenal     1      Mesut Ozil
# 2  35  Arsenal     2       Petr Cech
# 3  28  Arsenal     3    Theo Walcott

# %%
# You should this way
players.sort_index(axis=1)
# Out:
#    age     club  index            name
# 0   28  Arsenal      0  Alexis Sanchez
# 1   28  Arsenal      1      Mesut Ozil
# 2   35  Arsenal      2       Petr Cech
# 3   28  Arsenal      3    Theo Walcott

# %% [markdown]
# ## Skill Chellenge

# %% [markdown]
# ##### Sort the player dataframe by age in ascending order. Who the youngest footballer in the EPL

# %%
player.sort_values(by='age',ascending=True).head(1)
# Out:
#      index          name       club  age position  position_cat  market_value  \
# 237    237  Ben Woodburn  Liverpool   17       LW             1           1.5
#
#      page_views  fpl_value fpl_sel  fpl_points  region nationality  \
# 237        1241        4.5   0.10%           5       1       Wales
#
#      new_foreign  age_cat  club_id  big_club  new_signing
# 237            0        1       10         1            0

# %%
# idxmin
player.iloc[player.age.idxmin()]
# Out:
# index                    237
# name            Ben Woodburn
# club               Liverpool
# age                       17
# position                  LW
# position_cat               1
# market_value             1.5
# page_views              1241
# fpl_value                4.5
# fpl_sel                0.10%
# fpl_points                 5
# region                     1
# nationality            Wales
# new_foreign                0
# age_cat                    1
# club_id                   10
# big_club                   1
# new_signing                0
# Name: 237, dtype: object

# %%
a=player.sort_values(by='age',ascending=True).head(1)

# %%
a
# Out:
#      index          name       club  age position  position_cat  market_value  \
# 237    237  Ben Woodburn  Liverpool   17       LW             1           1.5
#
#      page_views  fpl_value fpl_sel  fpl_points  region nationality  \
# 237        1241        4.5   0.10%           5       1       Wales
#
#      new_foreign  age_cat  club_id  big_club  new_signing
# 237            0        1       10         1            0

# %%
a.loc[:,['name','age','market_value']]
# Out:
#              name  age  market_value
# 237  Ben Woodburn   17           1.5

# %%
a.set_index('name',inplace=True,drop=False)

# %%
a
# Out:
#               index          name       club  age position  position_cat  \
# name
# Ben Woodburn    237  Ben Woodburn  Liverpool   17       LW             1
#
#               market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# name
# Ben Woodburn           1.5        1241        4.5   0.10%           5       1
#
#              nationality  new_foreign  age_cat  club_id  big_club  new_signing
# name
# Ben Woodburn       Wales            0        1       10         1            0

# %%
a.loc[:,['name','age','market_value']]
# Out:
#                       name  age  market_value
# name
# Ben Woodburn  Ben Woodburn   17           1.5

# %% [markdown]
# #### Set the club columns as the index of the dataframe.then sort the dataframe index in alphabetical order. Make sure these change are applied to the underlying dataframe and carry over to the next question

# %%
b=player.set_index('club').sort_index()

# %%
b
# Out:
#           index                 name  age position  position_cat  \
# club
# Arsenal       0       Alexis Sanchez   28       LW             1
# Arsenal       1           Mesut Ozil   28       AM             1
# Arsenal       2            Petr Cech   35       GK             4
# Arsenal       3         Theo Walcott   28       RW             1
# Arsenal       4    Laurent Koscielny   31       CB             3
# ...         ...                  ...  ...      ...           ...
# West+Ham    460  Edimilson Fernandes   21       CM             2
# West+Ham    461       Arthur Masuaku   23       LB             3
# West+Ham    462            Sam Byram   23       RB             3
# West+Ham    463      Ashley Fletcher   21       CF             1
# West+Ham    464         Diafra Sakho   27       CF             1
#
#           market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# club
# Arsenal           65.0        4329       12.0  17.10%         264       3
# ...

# %% [markdown]
# #### Sort the dataframe values by club and market_value where the club is alphabetical and the market_value is the descending order (Which each team the most valuable players first)

# %%
c=player.sort_values(by=['club','market_value'], ascending=[True,False])

# %%
c.head()
# Out:
#     index                 name     club  age position  position_cat  \
# 0       0       Alexis Sanchez  Arsenal   28       LW             1
# 1       1           Mesut Ozil  Arsenal   28       AM             1
# 31     31  Alexandre Lacazette  Arsenal   26       CF             1
# 10     10         Granit Xhaka  Arsenal   24       DM             2
# 11     11         Granit Xhaka  Arsenal   24       DM             2
#
#     market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 0           65.0        4329       12.0  17.10%         264       3
# 1           50.0        4395        9.5   5.60%         167       2
# 31          40.0        1183       10.5  26.50%           0       2
# 10          35.0        1815        5.5   2.00%          85       2
# 11          35.0        1815        5.5   2.00%          85       2
#
#     nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 0         Chile            0        4        1         1            0
# ...

# %% [markdown]
# ### Identifying Duplicates

# %%
player.head()
# Out:
#    index               name     club  age position  position_cat  \
# 0      0     Alexis Sanchez  Arsenal   28       LW             1
# 1      1         Mesut Ozil  Arsenal   28       AM             1
# 2      2          Petr Cech  Arsenal   35       GK             4
# 3      3       Theo Walcott  Arsenal   28       RW             1
# 4      4  Laurent Koscielny  Arsenal   31       CB             3
#
#    market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 0          65.0        4329       12.0  17.10%         264       3
# 1          50.0        4395        9.5   5.60%         167       2
# 2           7.0        1529        5.5   5.90%         134       2
# 3          20.0        2393        7.5   1.50%         122       1
# 4          22.0         912        6.0   0.70%         121       2
#
#       nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 0           Chile            0        4        1         1            0
# ...

# %%
player.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 460    False
# 461    False
# 462    False
# 463    False
# 464    False
# Length: 465, dtype: bool

# %%
player[player.duplicated()]
# Out:
# Empty DataFrame
# Columns: [index, name, club, age, position, position_cat, market_value, page_views, fpl_value, fpl_sel, fpl_points, region, nationality, new_foreign, age_cat, club_id, big_club, new_signing]
# Index: []

# %%
# The subset parameter
# Unique ==> club, age, position, market_value
player.loc[player.duplicated(subset=['club', 'age', 'position', 'market_value'])].shape
# Out:
# (7, 18)

# %% [markdown]
# ## What counts as a DUPLICATED?
#        DEFAULT:
#          --records with repeating values across all columns
#        CUSTOM:
#            --could be changed to a smaller group of attributes using the subset parameter
#
#
# ## Which is the  orginal?
#
#         DEFAULT:
#             --The first occurances is marked as the orginal
#         CUSTOME:
#             --Could be changed to 'first', 'last', 'neither' using the keep parameter

# %%
# keep ='first' ,first is orginal, 'last', last is orginal
# keep =False, all is orginal
player.loc[player.duplicated(subset=['club', 'age', 'position', 'market_value'],keep='first')]
# Out:
#      index                     name               club  age position  \
# 11      11             Granit Xhaka            Arsenal   24       DM
# 13      13  Alex Oxlade-Chamberlain            Arsenal   23       RM
# 23      23  Alex Oxlade-Chamberlain            Arsenal   23       RM
# 59      59              Shane Duffy  Brighton+and+Hove   25       CB
# 260    260                 Fernando    Manchester+City   32       DM
# 279    279           Chris Smalling  Manchester+United   27       CB
# 293    293                Lascelles   Newcastle+United   27       CB
#
#      position_cat  market_value  page_views  fpl_value fpl_sel  fpl_points  \
# 11              2          35.0        1815        5.5   2.00%          85
# 13              2          22.0        1519        6.0   1.80%          83
# 23              2          22.0        1519        6.0   1.80%          83
# 59              3           5.0         243        4.5   0.60%           0
# ...

# %% [markdown]
# ### Removing Diplicates Records

# %%
player[player.duplicated(subset=None,keep='first')]
# Out:
# Empty DataFrame
# Columns: [index, name, club, age, position, position_cat, market_value, page_views, fpl_value, fpl_sel, fpl_points, region, nationality, new_foreign, age_cat, club_id, big_club, new_signing]
# Index: []

# %%
player.market_value.mean()
# Out:
# 11.125649350649349

# %%
# it is drop duplicate value
# Duplicate are not necessary bad all the case, something aware of
player.drop_duplicates(keep=False).market_value.mean()
# Out:
# 11.125649350649349

# %% [markdown]
# ### Removing DataFrame Rows

# %%
player[player.duplicated()]
# Out:
# Empty DataFrame
# Columns: [index, name, club, age, position, position_cat, market_value, page_views, fpl_value, fpl_sel, fpl_points, region, nationality, new_foreign, age_cat, club_id, big_club, new_signing]
# Index: []

# %%
# drop data by drop method the way of labels
player.drop(labels=11,axis=0)
# Out:
#      index                 name      club  age position  position_cat  \
# 0        0       Alexis Sanchez   Arsenal   28       LW             1
# 1        1           Mesut Ozil   Arsenal   28       AM             1
# 2        2            Petr Cech   Arsenal   35       GK             4
# 3        3         Theo Walcott   Arsenal   28       RW             1
# 4        4    Laurent Koscielny   Arsenal   31       CB             3
# ..     ...                  ...       ...  ...      ...           ...
# 460    460  Edimilson Fernandes  West+Ham   21       CM             2
# 461    461       Arthur Masuaku  West+Ham   23       LB             3
# 462    462            Sam Byram  West+Ham   23       RB             3
# 463    463      Ashley Fletcher  West+Ham   21       CF             1
# 464    464         Diafra Sakho  West+Ham   27       CF             1
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# ...

# %%
# Removing single rows by drop method
player.drop(index=11)
# Out:
#      index                 name      club  age position  position_cat  \
# 0        0       Alexis Sanchez   Arsenal   28       LW             1
# 1        1           Mesut Ozil   Arsenal   28       AM             1
# 2        2            Petr Cech   Arsenal   35       GK             4
# 3        3         Theo Walcott   Arsenal   28       RW             1
# 4        4    Laurent Koscielny   Arsenal   31       CB             3
# ..     ...                  ...       ...  ...      ...           ...
# 460    460  Edimilson Fernandes  West+Ham   21       CM             2
# 461    461       Arthur Masuaku  West+Ham   23       LB             3
# 462    462            Sam Byram  West+Ham   23       RB             3
# 463    463      Ashley Fletcher  West+Ham   21       CF             1
# 464    464         Diafra Sakho  West+Ham   27       CF             1
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# ...

# %%
# drop multiple rows by drop method
player.drop(index=[11,23,13])
# Out:
#      index                 name      club  age position  position_cat  \
# 0        0       Alexis Sanchez   Arsenal   28       LW             1
# 1        1           Mesut Ozil   Arsenal   28       AM             1
# 2        2            Petr Cech   Arsenal   35       GK             4
# 3        3         Theo Walcott   Arsenal   28       RW             1
# 4        4    Laurent Koscielny   Arsenal   31       CB             3
# ..     ...                  ...       ...  ...      ...           ...
# 460    460  Edimilson Fernandes  West+Ham   21       CM             2
# 461    461       Arthur Masuaku  West+Ham   23       LB             3
# 462    462            Sam Byram  West+Ham   23       RB             3
# 463    463      Ashley Fletcher  West+Ham   21       CF             1
# 464    464         Diafra Sakho  West+Ham   27       CF             1
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# ...

# %% [markdown]
# ### Removing Columns

# %%
# If you want to remove coulmns, set columns labels names
player.drop(labels='name',axis=1)
# Out:
#      index      club  age position  position_cat  market_value  page_views  \
# 0        0   Arsenal   28       LW             1          65.0        4329
# 1        1   Arsenal   28       AM             1          50.0        4395
# 2        2   Arsenal   35       GK             4           7.0        1529
# 3        3   Arsenal   28       RW             1          20.0        2393
# 4        4   Arsenal   31       CB             3          22.0         912
# ..     ...       ...  ...      ...           ...           ...         ...
# 460    460  West+Ham   21       CM             2           5.0         288
# 461    461  West+Ham   23       LB             3           7.0         199
# 462    462  West+Ham   23       RB             3           4.5         198
# 463    463  West+Ham   21       CF             1           1.0         412
# 464    464  West+Ham   27       CF             1          10.0         214
#
# ...

# %%
player.drop(columns='name')
# Out:
#      index      club  age position  position_cat  market_value  page_views  \
# 0        0   Arsenal   28       LW             1          65.0        4329
# 1        1   Arsenal   28       AM             1          50.0        4395
# 2        2   Arsenal   35       GK             4           7.0        1529
# 3        3   Arsenal   28       RW             1          20.0        2393
# 4        4   Arsenal   31       CB             3          22.0         912
# ..     ...       ...  ...      ...           ...           ...         ...
# 460    460  West+Ham   21       CM             2           5.0         288
# 461    461  West+Ham   23       LB             3           7.0         199
# 462    462  West+Ham   23       RB             3           4.5         198
# 463    463  West+Ham   21       CF             1           1.0         412
# 464    464  West+Ham   27       CF             1          10.0         214
#
# ...

# %%
# Removing cloumns by drop method
player.drop(columns=['name','age'])
# Out:
#      index      club position  position_cat  market_value  page_views  \
# 0        0   Arsenal       LW             1          65.0        4329
# 1        1   Arsenal       AM             1          50.0        4395
# 2        2   Arsenal       GK             4           7.0        1529
# 3        3   Arsenal       RW             1          20.0        2393
# 4        4   Arsenal       CB             3          22.0         912
# ..     ...       ...      ...           ...           ...         ...
# 460    460  West+Ham       CM             2           5.0         288
# 461    461  West+Ham       LB             3           7.0         199
# 462    462  West+Ham       RB             3           4.5         198
# 463    463  West+Ham       CF             1           1.0         412
# 464    464  West+Ham       CF             1          10.0         214
#
#      fpl_value fpl_sel  fpl_points  region     nationality  new_foreign  \
# ...

# %% [markdown]
# ## to pop() or not
#     3 points to consider
#         1.pop() works on a single columns at a time
#         2.pop() returns the removed('popped') column as a series
#         3.pop() modifies the underlying dataframe(operates inplace)

# %%
player.pop('name')
# Out:
# 0           Alexis Sanchez
# 1               Mesut Ozil
# 2                Petr Cech
# 3             Theo Walcott
# 4        Laurent Koscielny
#               ...
# 460    Edimilson Fernandes
# 461         Arthur Masuaku
# 462              Sam Byram
# 463        Ashley Fletcher
# 464           Diafra Sakho
# Name: name, Length: 465, dtype: object

# %%
# pop() works single values only
# player.pop(['name','age'])

# %% [markdown]
# ### A Sophisticated Alternative

# %%
# Reindex to remove rows/columns
player.reindex(index=[0,3,2])
# Out:
#    index     club  age position  position_cat  market_value  page_views  \
# 0      0  Arsenal   28       LW             1          65.0        4329
# 3      3  Arsenal   28       RW             1          20.0        2393
# 2      2  Arsenal   35       GK             4           7.0        1529
#
#    fpl_value fpl_sel  fpl_points  region     nationality  new_foreign  \
# 0       12.0  17.10%         264       3           Chile            0
# 3        7.5   1.50%         122       1         England            0
# 2        5.5   5.90%         134       2  Czech Republic            0
#
#    age_cat  club_id  big_club  new_signing
# 0        4        1         1            0
# 3        4        1         1            0
# 2        6        1         1            0

# %%
player.reindex(index=set(player.index))
# Out:
#      index      club  age position  position_cat  market_value  page_views  \
# 0        0   Arsenal   28       LW             1          65.0        4329
# 1        1   Arsenal   28       AM             1          50.0        4395
# 2        2   Arsenal   35       GK             4           7.0        1529
# 3        3   Arsenal   28       RW             1          20.0        2393
# 4        4   Arsenal   31       CB             3          22.0         912
# ..     ...       ...  ...      ...           ...           ...         ...
# 460    460  West+Ham   21       CM             2           5.0         288
# 461    461  West+Ham   23       LB             3           7.0         199
# 462    462  West+Ham   23       RB             3           4.5         198
# 463    463  West+Ham   21       CF             1           1.0         412
# 464    464  West+Ham   27       CF             1          10.0         214
#
# ...

# %%
unwanted_rows=[1,2,3,4]
unwanted_columns=['name','age','club']
player.reindex(index=set(player.index).difference(unwanted_rows),columns=set(player.columns).difference(unwanted_columns))
# Out:
#      club_id  new_signing  position_cat  nationality  big_club  market_value  \
# 0          1            0             1        Chile         1          65.0
# 5          1            0             3        Spain         1          30.0
# 6          1            0             1       France         1          22.0
# 7          1            0             3        Spain         1          13.0
# 8          1            1             3      Germany         1          30.0
# ..       ...          ...           ...          ...       ...           ...
# 460       20            1             2  Switzerland         0           5.0
# 461       20            1             3     Congo DR         0           7.0
# 462       20            0             3      England         0           4.5
# 463       20            1             1      England         0           1.0
# 464       20            0             1      Senegal         0          10.0
#
# ...

# %% [markdown]
# #### Drop Method is the best for removing any row and columns

# %% [markdown]
# ## Null values in DataFrame

# %%
data_url='https://andybek.com/pandas-soccer'
pl=pd.read_csv(data_url)

# %%
pl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 465 entries, 0 to 464
# Data columns (total 17 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          465 non-null    object
#  1   club          465 non-null    object
#  2   age           465 non-null    int64
#  3   position      464 non-null    object
#  4   position_cat  465 non-null    int64
#  5   market_value  462 non-null    float64
#  6   page_views    465 non-null    int64
#  7   fpl_value     465 non-null    float64
#  8   fpl_sel       465 non-null    object
#  9   fpl_points    465 non-null    int64
#  10  region        465 non-null    int64
#  11  nationality   465 non-null    object
#  12  new_foreign   465 non-null    int64
#  13  age_cat       465 non-null    int64
#  14  club_id       465 non-null    int64
#  15  big_club      465 non-null    int64
#  16  new_signing   465 non-null    int64
# dtypes: float64(2), int64(10), object(5)
# ...

# %%
ages = pl.age

# %%
type(ages)
# Out:
# pandas.core.series.Series

# %%
# No Have null values beacuse series is an empty array
ages[ages.isna()]
# Out:
# Series([], Name: age, dtype: int64)

# %%
# Also work isna() work in dataframe
pl.isna()
# Out:
#       name   club    age  position  position_cat  market_value  page_views  \
# 0    False  False  False     False         False         False       False
# 1    False  False  False     False         False         False       False
# 2    False  False  False     False         False         False       False
# 3    False  False  False     False         False         False       False
# 4    False  False  False     False         False         False       False
# ..     ...    ...    ...       ...           ...           ...         ...
# 460  False  False  False     False         False         False       False
# 461  False  False  False     False         False         False       False
# 462  False  False  False     False         False         False       False
# 463  False  False  False     False         False         False       False
# 464  False  False  False     False         False         False       False
#
# ...

# %% [markdown]
# #### How many NAs are there is this dataframe?

# %%
# 4 NAs values has in our dataframe 
np.count_nonzero(pl.isna())
# Out:
# 4

# %% [markdown]
# #### Which records have NAs is this datafram?

# %%
# not working this way ,it is does not produce meaning items
pl[pl.isna()]
# Out:
#     name club  age position  position_cat  market_value  page_views  \
# 0    NaN  NaN  NaN      NaN           NaN           NaN         NaN
# 1    NaN  NaN  NaN      NaN           NaN           NaN         NaN
# 2    NaN  NaN  NaN      NaN           NaN           NaN         NaN
# 3    NaN  NaN  NaN      NaN           NaN           NaN         NaN
# 4    NaN  NaN  NaN      NaN           NaN           NaN         NaN
# ..   ...  ...  ...      ...           ...           ...         ...
# 460  NaN  NaN  NaN      NaN           NaN           NaN         NaN
# 461  NaN  NaN  NaN      NaN           NaN           NaN         NaN
# 462  NaN  NaN  NaN      NaN           NaN           NaN         NaN
# 463  NaN  NaN  NaN      NaN           NaN           NaN         NaN
# 464  NaN  NaN  NaN      NaN           NaN           NaN         NaN
#
#      fpl_value fpl_sel  fpl_points  region nationality  new_foreign  age_cat  \
# ...

# %%
pl.isna().values
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])

# %%
pl[pl.isna().values].drop_duplicates()
# Out:
#                   name            club  age position  position_cat  \
# 30        Granit Xhaka         Arsenal   24      NaN             2
# 192       Steve Mounie    Huddersfield   22       CF             1
# 195  Kasper Schmeichel  Leicester+City   30       GK             4
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 30            NaN        1815        5.5   2.00%          85       2
# 192           NaN          56        6.0   0.60%           0       2
# 195           NaN        1601        5.0   2.40%         109       2
#
#      nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 30   Switzerland            0        2        1         1            0
# 192        Benin            0        2        8         0            0
# 195      Denmark            0        4        9         0            0

# %% [markdown]
# ###  Droping and Filling DataFrame NAs

# %%
# NAs values filling with full name
pl.fillna('full').loc[[30,192,195]]
# Out:
#                   name            club  age position  position_cat  \
# 30        Granit Xhaka         Arsenal   24     full             2
# 192       Steve Mounie    Huddersfield   22       CF             1
# 195  Kasper Schmeichel  Leicester+City   30       GK             4
#
#     market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 30          full        1815        5.5   2.00%          85       2
# 192         full          56        6.0   0.60%           0       2
# 195         full        1601        5.0   2.40%         109       2
#
#      nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 30   Switzerland            0        2        1         1            0
# 192        Benin            0        2        8         0            0
# 195      Denmark            0        4        9         0            0

# %%
# Dynamic Way Replace NAs values
pl.fillna({
    'market_value':pl.market_value.mean(),
    'position':'RB'
}).loc[[30,192,195]]
# Out:
#                   name            club  age position  position_cat  \
# 30        Granit Xhaka         Arsenal   24       RB             2
# 192       Steve Mounie    Huddersfield   22       CF             1
# 195  Kasper Schmeichel  Leicester+City   30       GK             4
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 30      11.125649        1815        5.5   2.00%          85       2
# 192     11.125649          56        6.0   0.60%           0       2
# 195     11.125649        1601        5.0   2.40%         109       2
#
#      nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 30   Switzerland            0        2        1         1            0
# 192        Benin            0        2        8         0            0
# 195      Denmark            0        4        9         0            0

# %%
# How about droping NAs values?
pl.dropna()
# Out:
#                     name      club  age position  position_cat  market_value  \
# 0         Alexis Sanchez   Arsenal   28       LW             1          65.0
# 1             Mesut Ozil   Arsenal   28       AM             1          50.0
# 2              Petr Cech   Arsenal   35       GK             4           7.0
# 3           Theo Walcott   Arsenal   28       RW             1          20.0
# 4      Laurent Koscielny   Arsenal   31       CB             3          22.0
# ..                   ...       ...  ...      ...           ...           ...
# 460  Edimilson Fernandes  West+Ham   21       CM             2           5.0
# 461       Arthur Masuaku  West+Ham   23       LB             3           7.0
# 462            Sam Byram  West+Ham   23       RB             3           4.5
# 463      Ashley Fletcher  West+Ham   21       CF             1           1.0
# 464         Diafra Sakho  West+Ham   27       CF             1          10.0
#
# ...

# %%
# Droping columns
pl.dropna(axis=1).loc[[30,192,195]]
# Out:
#                   name            club  age  position_cat  page_views  \
# 30        Granit Xhaka         Arsenal   24             2        1815
# 192       Steve Mounie    Huddersfield   22             1          56
# 195  Kasper Schmeichel  Leicester+City   30             4        1601
#
#      fpl_value fpl_sel  fpl_points  region  nationality  new_foreign  age_cat  \
# 30         5.5   2.00%          85       2  Switzerland            0        2
# 192        6.0   0.60%           0       2        Benin            0        2
# 195        5.0   2.40%         109       2      Denmark            0        4
#
#      club_id  big_club  new_signing
# 30         1         1            0
# 192        8         0            0
# 195        9         0            0

# %% [markdown]
# ### Method and Axes with fillna()

# %%
pl[pl.isna().values].drop_duplicates()
# Out:
#                   name            club  age position  position_cat  \
# 30        Granit Xhaka         Arsenal   24      NaN             2
# 192       Steve Mounie    Huddersfield   22       CF             1
# 195  Kasper Schmeichel  Leicester+City   30       GK             4
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 30            NaN        1815        5.5   2.00%          85       2
# 192           NaN          56        6.0   0.60%           0       2
# 195           NaN        1601        5.0   2.40%         109       2
#
#      nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 30   Switzerland            0        2        1         1            0
# 192        Benin            0        2        8         0            0
# 195      Denmark            0        4        9         0            0

# %%
pl.fillna(method='ffill',axis=0).loc[[30,192,195]]
# Out:
#                   name            club  age position  position_cat  \
# 30        Granit Xhaka         Arsenal   24       LB             2
# 192       Steve Mounie    Huddersfield   22       CF             1
# 195  Kasper Schmeichel  Leicester+City   30       GK             4
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 30           15.0        1815        5.5   2.00%          85       2
# 192           3.0          56        6.0   0.60%           0       2
# 195          30.0        1601        5.0   2.40%         109       2
#
#      nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 30   Switzerland            0        2        1         1            0
# 192        Benin            0        2        8         0            0
# 195      Denmark            0        4        9         0            0

# %% [markdown]
# ####
#     Axis = 0, fillling NAs value vertically
#     Axis = 1, fillling NAs value horizontally

# %%
# method = 'bfill'-->'pad', 'ffill'--> 'backfill',  
pl.fillna(method='ffill',axis=0).loc[[30,192,195]]
# Out:
#                   name            club  age position  position_cat  \
# 30        Granit Xhaka         Arsenal   24       LB             2
# 192       Steve Mounie    Huddersfield   22       CF             1
# 195  Kasper Schmeichel  Leicester+City   30       GK             4
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 30           15.0        1815        5.5   2.00%          85       2
# 192           3.0          56        6.0   0.60%           0       2
# 195          30.0        1601        5.0   2.40%         109       2
#
#      nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 30   Switzerland            0        2        1         1            0
# 192        Benin            0        2        8         0            0
# 195      Denmark            0        4        9         0            0

# %% [markdown]
# ## Skill Challenge
#
#     1.From our players dataframe remove the rows labeled 2,10,21 and the market_value columns.Do not modify the underlying dataframe.Assign the result to df2

# %%
df2 = pl.drop(index = [2,10,21],columns='market_value')

# %%
df2.head()
# Out:
#                 name     club  age position  position_cat  page_views  \
# 0     Alexis Sanchez  Arsenal   28       LW             1        4329
# 1         Mesut Ozil  Arsenal   28       AM             1        4395
# 3       Theo Walcott  Arsenal   28       RW             1        2393
# 4  Laurent Koscielny  Arsenal   31       CB             3         912
# 5    Hector Bellerin  Arsenal   22       RB             3        1675
#
#    fpl_value fpl_sel  fpl_points  region nationality  new_foreign  age_cat  \
# 0       12.0  17.10%         264       3       Chile            0        4
# 1        9.5   5.60%         167       2     Germany            0        4
# 3        7.5   1.50%         122       1     England            0        4
# 4        6.0   0.70%         121       2      France            0        4
# 5        6.0  13.70%         119       2       Spain            0        2
#
#    club_id  big_club  new_signing
# 0        1         1            0
# ...

# %% [markdown]
# #### Does the nationality columns in df2 contain any NA values? How many unique nationalities are there?

# %%
np.count_nonzero(df2.nationality.isna())
# Out:
# 0

# %%
df2.nationality.isna().sum()
# Out:
# 0

# %%
df2.nationality.unique().size
# Out:
# 61

# %%
df2.nationality.drop_duplicates().size
# Out:
# 61

# %%
df2.nationality.nunique()
# Out:
# 61

# %% [markdown]
# #### Starting from df2, isolate a dataframe slice of players that contains only the unique age position combinations for each club.Do not include the club column itself?

# %%
df2.drop_duplicates(subset=['age','club','position'],keep='first').loc[:,['age','position']]
# Out:
#      age position
# 0     28       LW
# 1     28       AM
# 3     28       RW
# 4     31       CB
# 5     22       RB
# ..   ...      ...
# 460   21       CM
# 461   23       LB
# 462   23       RB
# 463   21       CF
# 464   27       CF
#
# [433 rows x 2 columns]

# %% [markdown]
# ## Calculating Aggregates With agg()

# %%
pl.head()
# Out:
#                 name     club  age position  position_cat  market_value  \
# 0     Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1         Mesut Ozil  Arsenal   28       AM             1          50.0
# 2          Petr Cech  Arsenal   35       GK             4           7.0
# 3       Theo Walcott  Arsenal   28       RW             1          20.0
# 4  Laurent Koscielny  Arsenal   31       CB             3          22.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# 1        4395        9.5   5.60%         167       2         Germany
# 2        1529        5.5   5.90%         134       2  Czech Republic
# 3        2393        7.5   1.50%         122       1         England
# 4         912        6.0   0.70%         121       2          France
#
#    new_foreign  age_cat  club_id  big_club  new_signing
# 0            0        4        1         1            0
# ...

# %%
# Agg() return mean values every columns of the dataframe
pl.agg('mean')
# Out:
# age              26.776344
# position_cat      2.178495
# market_value     11.125649
# page_views      771.546237
# fpl_value         5.450538
# fpl_points       57.544086
# region            1.989247
# new_foreign       0.034409
# age_cat           3.195699
# club_id          10.253763
# big_club          0.309677
# new_signing       0.144086
# dtype: float64

# %%
pl.age.mean()
# Out:
# 26.776344086021506

# %%
# pl.agg(min)
pl.agg(np.min)
# Out:
# name            Aaron Cresswell
# club                    Arsenal
# age                          17
# position_cat                  1
# market_value               0.05
# page_views                    3
# fpl_value                   4.0
# fpl_sel                   0.00%
# fpl_points                    0
# region                        1
# nationality             Algeria
# new_foreign                   0
# age_cat                       1
# club_id                       1
# big_club                      0
# new_signing                   0
# dtype: object

# %%
# >, < ,<=, >= should have some meaning
'a' > 'b'
# Out:
# False

# %%
# every character associated with integer which is unicode
ord('a')
# Out:
# 97

# %%
ord('b')
# Out:
# 98

# %%
ls = ['a','b','c','day']
max(ls)
# Out:
# 'day'

# %%
ord('d')
# Out:
# 100

# %% [markdown]
# #### Comparision operator is not supported between float,int and string

# %%
# Comparision operator is not supported between float,int and string
# ls = ['a','b','c','day',16]
# max(ls)

# %%
pl.agg('max')
# Out:
# name            Åukasz FabiaÅ„ski
# club                      West+Ham
# age                             38
# position_cat                     4
# market_value                  75.0
# page_views                    7664
# fpl_value                     12.5
# fpl_sel                      9.70%
# fpl_points                     264
# region                           4
# nationality                  Wales
# new_foreign                      1
# age_cat                          6
# club_id                         20
# big_club                         1
# new_signing                      1
# dtype: object

# %% [markdown]
# #### select_dtypes() -->  to pre filter columns by types

# %%
pl.select_dtypes(np.number).agg('max')
# Out:
# age               38.0
# position_cat       4.0
# market_value      75.0
# page_views      7664.0
# fpl_value         12.5
# fpl_points       264.0
# region             4.0
# new_foreign        1.0
# age_cat            6.0
# club_id           20.0
# big_club           1.0
# new_signing        1.0
# dtype: float64

# %%
pl.select_dtypes(np.number).agg(['min','max','mean'])
# Out:
#             age  position_cat  market_value   page_views  fpl_value  \
# min   17.000000      1.000000      0.050000     3.000000   4.000000
# max   38.000000      4.000000     75.000000  7664.000000  12.500000
# mean  26.776344      2.178495     11.125649   771.546237   5.450538
#
#       fpl_points    region  new_foreign   age_cat    club_id  big_club  \
# min     0.000000  1.000000     0.000000  1.000000   1.000000  0.000000
# max   264.000000  4.000000     1.000000  6.000000  20.000000  1.000000
# mean   57.544086  1.989247     0.034409  3.195699  10.253763  0.309677
#
#       new_signing
# min      0.000000
# max      1.000000
# mean     0.144086

# %% [markdown]
# ### Same - shape Transforms

# %%
pl.head(2)
# Out:
#              name     club  age position  position_cat  market_value  \
# 0  Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1      Mesut Ozil  Arsenal   28       AM             1          50.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region nationality  new_foreign  \
# 0        4329       12.0  17.10%         264       3       Chile            0
# 1        4395        9.5   5.60%         167       2     Germany            0
#
#    age_cat  club_id  big_club  new_signing
# 0        4        1         1            0
# 1        4        1         1            0

# %%
def random_case(x):
    return x * .91

# %%
pl.loc[:,['market_value','fpl_value']].transform(lambda x:x * 0.91)
# Out:
#      market_value  fpl_value
# 0          59.150     10.920
# 1          45.500      8.645
# 2           6.370      5.005
# 3          18.200      6.825
# 4          20.020      5.460
# ..            ...        ...
# 460         4.550      4.095
# 461         6.370      4.095
# 462         4.095      4.095
# 463         0.910      4.095
# 464         9.100      5.005
#
# [465 rows x 2 columns]

# %%
pl.loc[:,['market_value','fpl_value']].transform(random_case)
# Out:
#      market_value  fpl_value
# 0          59.150     10.920
# 1          45.500      8.645
# 2           6.370      5.005
# 3          18.200      6.825
# 4          20.020      5.460
# ..            ...        ...
# 460         4.550      4.095
# 461         6.370      4.095
# 462         4.095      4.095
# 463         0.910      4.095
# 464         9.100      5.005
#
# [465 rows x 2 columns]

# %%
pl.loc[:,['market_value','fpl_value']] * .91
# Out:
#      market_value  fpl_value
# 0          59.150     10.920
# 1          45.500      8.645
# 2           6.370      5.005
# 3          18.200      6.825
# 4          20.020      5.460
# ..            ...        ...
# 460         4.550      4.095
# 461         6.370      4.095
# 462         4.095      4.095
# 463         0.910      4.095
# 464         9.100      5.005
#
# [465 rows x 2 columns]

# %% [markdown]
# ### Choice() --> Select random item from sequence of values

# %%
# Choice method
from random import choice

# %%
name = ['bread','banana','milk']

# %%
choice(name)
# Out:
# 'banana'

# %%
# str method

# %%
'banana'.upper()
# Out:
# 'BANANA'

# %%
s = pd.Series(name)

# %% [markdown]
# ##### # Series is not have method like upper, lower etc

# %%
# s.upper()

# %%
s.str.upper()
# Out:
# 0     BREAD
# 1    BANANA
# 2      MILK
# dtype: object

# %% [markdown]
# #### Random Transformation Function
#     The function should:
#         1.Apply a random string capitalization method
#         2. to a sequence of values and
#         3.return the transformed sequence

# %%
def random_cases(x):
    func = [x.str.title, x.str.lower, x.str.upper]
    return choice(func)()

# %%
pl.select_dtypes(include=object).transform(random_cases)
# Out:
#                     name      club position fpl_sel     nationality
# 0         ALEXIS SANCHEZ   ARSENAL       lw  17.10%           Chile
# 1             MESUT OZIL   ARSENAL       am   5.60%         Germany
# 2              PETR CECH   ARSENAL       gk   5.90%  Czech Republic
# 3           THEO WALCOTT   ARSENAL       rw   1.50%         England
# 4      LAURENT KOSCIELNY   ARSENAL       cb   0.70%          France
# ..                   ...       ...      ...     ...             ...
# 460  EDIMILSON FERNANDES  WEST+HAM       cm   0.40%     Switzerland
# 461       ARTHUR MASUAKU  WEST+HAM       lb   0.20%        Congo Dr
# 462            SAM BYRAM  WEST+HAM       rb   0.30%         England
# 463      ASHLEY FLETCHER  WEST+HAM       cf   5.90%         England
# 464         DIAFRA SAKHO  WEST+HAM       cf   0.10%         Senegal
#
# [465 rows x 5 columns]

# %%
for i in range(3):
    print(pl.select_dtypes(include=object).transform(random_cases).head())
# Out:
#                 name     club position fpl_sel     nationality
# 0     Alexis Sanchez  ARSENAL       Lw  17.10%           chile
# 1         Mesut Ozil  ARSENAL       Am   5.60%         germany
# 2          Petr Cech  ARSENAL       Gk   5.90%  czech republic
# 3       Theo Walcott  ARSENAL       Rw   1.50%         england
# 4  Laurent Koscielny  ARSENAL       Cb   0.70%          france
#                 name     club position fpl_sel     nationality
# 0     Alexis Sanchez  arsenal       LW  17.10%           Chile
# 1         Mesut Ozil  arsenal       AM   5.60%         Germany
# 2          Petr Cech  arsenal       GK   5.90%  Czech Republic
# 3       Theo Walcott  arsenal       RW   1.50%         England
# 4  Laurent Koscielny  arsenal       CB   0.70%          France
#                 name     club position fpl_sel     nationality
# 0     ALEXIS SANCHEZ  arsenal       LW  17.10%           CHILE
# 1         MESUT OZIL  arsenal       AM   5.60%         GERMANY
# ...

# %% [markdown]
# ### Flexibility with apply()
#     * When apply apply() method?
#         -- Whenever we want to apply a given function to an entire row or columns
#         Apply() -> capable aggregation and transform
#         Transform() --> it is capable only transformation not aggregation

# %%
pl.head()
# Out:
#                 name     club  age position  position_cat  market_value  \
# 0     Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1         Mesut Ozil  Arsenal   28       AM             1          50.0
# 2          Petr Cech  Arsenal   35       GK             4           7.0
# 3       Theo Walcott  Arsenal   28       RW             1          20.0
# 4  Laurent Koscielny  Arsenal   31       CB             3          22.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# 1        4395        9.5   5.60%         167       2         Germany
# 2        1529        5.5   5.90%         134       2  Czech Republic
# 3        2393        7.5   1.50%         122       1         England
# 4         912        6.0   0.70%         121       2          France
#
#    new_foreign  age_cat  club_id  big_club  new_signing
# 0            0        4        1         1            0
# ...

# %%
def random_float(x):
    if x.dtype == np.float64:
        return round(x)
    return x

# %%
pl.select_dtypes(np.float64).head()
# Out:
#    market_value  fpl_value
# 0          65.0       12.0
# 1          50.0        9.5
# 2           7.0        5.5
# 3          20.0        7.5
# 4          22.0        6.0

# %%
pl.select_dtypes(np.float64).apply(random_float)
# Out:
#      market_value  fpl_value
# 0            65.0       12.0
# 1            50.0       10.0
# 2             7.0        6.0
# 3            20.0        8.0
# 4            22.0        6.0
# ..            ...        ...
# 460           5.0        4.0
# 461           7.0        4.0
# 462           4.0        4.0
# 463           1.0        4.0
# 464          10.0        6.0
#
# [465 rows x 2 columns]

# %%
# apply() = agg() + transform()

# %%
# apply() an aggreate
pl.apply('mean')
# Out:
# age              26.776344
# position_cat      2.178495
# market_value     11.125649
# page_views      771.546237
# fpl_value         5.450538
# fpl_points       57.544086
# region            1.989247
# new_foreign       0.034409
# age_cat           3.195699
# club_id          10.253763
# big_club          0.309677
# new_signing       0.144086
# dtype: float64

# %%
# transform() is not capable into agg()
# pl.transform('mean')

# %%
# fliping the axis param
# axis = 0, it is aggregate vertically
pl.apply('mean',axis=0)
# Out:
# age              26.776344
# position_cat      2.178495
# market_value     11.125649
# page_views      771.546237
# fpl_value         5.450538
# fpl_points       57.544086
# region            1.989247
# new_foreign       0.034409
# age_cat           3.195699
# club_id          10.253763
# big_club          0.309677
# new_signing       0.144086
# dtype: float64

# %%
# fliping the axis param
# axis = 0, it is aggregate horizontally
pl.apply('mean', axis=1)
# Out:
# 0      392.333333
# 1      388.208333
# 2      143.708333
# 3      214.875000
# 4       91.916667
#           ...
# 460     31.875000
# 461     24.791667
# 462     23.750000
# 463     39.875000
# 464     24.708333
# Length: 465, dtype: float64

# %%
# we have type error, because ,it has mix data types in the series
# pl.loc[460,:].mean()

# %%
# pl.loc[460,:].select_dtypes() --> only support dataframe not series

# %%
# importing to know
pl.loc[460,[dtype != object for dtype in pl.dtypes]]
# Out:
# age              21
# position_cat      2
# market_value    5.0
# page_views      288
# fpl_value       4.5
# fpl_points       38
# region            2
# new_foreign       0
# age_cat           1
# club_id          20
# big_club          0
# new_signing       1
# Name: 460, dtype: object

# %% [markdown]
# ### Element-wise operation with applymap()

# %%
# vectorize ops: agg(), transform(), appy()

# %% [markdown]
# #### Vectorization:
#     1.Made possibly by SIMD at the processor-level
#     2.Result in operation that are multiple times faster
#     3.Supported by numpy and by extension, pandas

# %%
infaltion = 1.02

# %%
mini_df = pl.loc[:, ["market_value","fpl_value"]]

# %%
mini_df * infaltion
# Out:
#      market_value  fpl_value
# 0           66.30      12.24
# 1           51.00       9.69
# 2            7.14       5.61
# 3           20.40       7.65
# 4           22.44       6.12
# ..            ...        ...
# 460          5.10       4.59
# 461          7.14       4.59
# 462          4.59       4.59
# 463          1.02       4.59
# 464         10.20       5.61
#
# [465 rows x 2 columns]

# %%
from datetime import datetime
count = 0
def log_and_transform(x):
    global count
    count += 1
    if count % 100 == 0:
        print(f'It is {datetime.now()} and i just adjusted the {count}th value')
    return x * infaltion

# %% [markdown]
# #### applymap() work only element wise transformation

# %%
mini_df.applymap(log_and_transform)
# Out:
# It is 2021-08-05 12:14:16.320211 and i just adjusted the 100th value
# It is 2021-08-05 12:14:16.320211 and i just adjusted the 200th value
# It is 2021-08-05 12:14:16.320211 and i just adjusted the 300th value
# It is 2021-08-05 12:14:16.320211 and i just adjusted the 400th value
# It is 2021-08-05 12:14:16.320211 and i just adjusted the 500th value
# It is 2021-08-05 12:14:16.320211 and i just adjusted the 600th value
# It is 2021-08-05 12:14:16.320211 and i just adjusted the 700th value
# It is 2021-08-05 12:14:16.320211 and i just adjusted the 800th value
# It is 2021-08-05 12:14:16.320211 and i just adjusted the 900th value
#      market_value  fpl_value
# 0           66.30      12.24
# 1           51.00       9.69
# 2            7.14       5.61
# 3           20.40       7.65
# 4           22.44       6.12
# ..            ...        ...
# 460          5.10       4.59
# 461          7.14       4.59
# 462          4.59       4.59
# 463          1.02       4.59
# ...

# %% [markdown]
# ## Skill chellenge

# %% [markdown]
# #### Create a standalone function that
#     *accepts a single parameter x
#     *returns the string 'relatively unknown' if x is less than 220
#     *'kind of popular' if x is between 220 and 600(non-inclusive)
#     *'popular' if x is between 600 and 2000(non-inclusive)
#     *super-popular otherwise

# %%
def standalone(x):
    if x < 200:
        return 'relatively unknown'
    if x < 600:
        return 'kind of popular'
    if x < 2000:
        return 'popular'
    else:
        return 'super popular'
    return x

# %%
standalone(200)
# Out:
# 'kind of popular'

# %%
standalone(20)
# Out:
# 'relatively unknown'

# %% [markdown]
# #### Apply the function the step above to the players page_views column. Use a method that supports vectorized operators

# %%
pl.page_views
# Out:
# 0      4329
# 1      4395
# 2      1529
# 3      2393
# 4       912
#        ...
# 460     288
# 461     199
# 462     198
# 463     412
# 464     214
# Name: page_views, Length: 465, dtype: int64

# %%
pl.page_views.apply(standalone)
# Out:
# 0           super popular
# 1           super popular
# 2                 popular
# 3           super popular
# 4                 popular
#               ...
# 460       kind of popular
# 461    relatively unknown
# 462    relatively unknown
# 463       kind of popular
# 464       kind of popular
# Name: page_views, Length: 465, dtype: object

# %% [markdown]
# #### Add the output from above as a new column to the players dataframe. Name the column popularity

# %%
popularity = pl.page_views.apply(standalone)

# %%
pl['popularity'] = pl.page_views.apply(standalone)

# %%
pl.head()
# Out:
#                 name     club  age position  position_cat  market_value  \
# 0     Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1         Mesut Ozil  Arsenal   28       AM             1          50.0
# 2          Petr Cech  Arsenal   35       GK             4           7.0
# 3       Theo Walcott  Arsenal   28       RW             1          20.0
# 4  Laurent Koscielny  Arsenal   31       CB             3          22.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# 1        4395        9.5   5.60%         167       2         Germany
# 2        1529        5.5   5.90%         134       2  Czech Republic
# 3        2393        7.5   1.50%         122       1         England
# 4         912        6.0   0.70%         121       2          France
#
#    new_foreign  age_cat  club_id  big_club  new_signing     popularity
# ...

# %% [markdown]
# #### How many 'super-popular' players are there?

# %%
pl.popularity.value_counts()['super popular']
# Out:
# 37

# %%
pl[pl.popularity == 'super popular']
# Out:
#                       name               club  age position  position_cat  \
# 0           Alexis Sanchez            Arsenal   28       LW             1
# 1               Mesut Ozil            Arsenal   28       AM             1
# 3             Theo Walcott            Arsenal   28       RW             1
# 6           Olivier Giroud            Arsenal   30       CF             1
# 24             Lucas Perez            Arsenal   28       CF             1
# 33           Jermain Defoe        Bournemouth   34       CF             1
# 96             Eden Hazard            Chelsea   26       LW             1
# 97             Diego Costa            Chelsea   28       CF             1
# 99   Marcos Alonso Mendoza            Chelsea   26       LB             3
# 103             David Luiz            Chelsea   30       CB             3
# 104          Cesc Fabregas            Chelsea   30       CM             2
# 106           Victor Moses            Chelsea   26       RM             2
# ...

# %% [markdown]
# ### Setting DataFrame Values

# %%
pl.head(2)
# Out:
#              name     club  age position  position_cat  market_value  \
# 0  Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1      Mesut Ozil  Arsenal   28       AM             1          50.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region nationality  new_foreign  \
# 0        4329       12.0  17.10%         264       3       Chile            0
# 1        4395        9.5   5.60%         167       2     Germany            0
#
#    age_cat  club_id  big_club  new_signing     popularity
# 0        4        1         1            0  super popular
# 1        4        1         1            0  super popular

# %%
# %%timeit
# Single value assign
pl.loc[0,'position'] = 'AM'
# Out:
# 375 µs ± 51 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# 27.59% is the faster than loc[] in at[]
298 / 10.8
# Out:
# 27.59259259259259

# %%
pl.head(1)
# Out:
#              name     club  age position  position_cat  market_value  \
# 0  Alexis Sanchez  Arsenal   28       AM             1          65.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region nationality  new_foreign  \
# 0        4329       12.0  17.10%         264       3       Chile            0
#
#    age_cat  club_id  big_club  new_signing     popularity
# 0        4        1         1            0  super popular

# %%
# %%timeit
# Single value assign
pl.iloc[0,3] = 'LW'
# Out:
# 218 µs ± 12.6 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
pl.head(2)
# Out:
#              name     club  age position  position_cat  market_value  \
# 0  Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1      Mesut Ozil  Arsenal   28       AM             1          50.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region nationality  new_foreign  \
# 0        4329       12.0  17.10%         264       3       Chile            0
# 1        4395        9.5   5.60%         167       2     Germany            0
#
#    age_cat  club_id  big_club  new_signing     popularity
# 0        4        1         1            0  super popular
# 1        4        1         1            0  super popular

# %% [markdown]
# #### at[] and iat[] should be preferred for single value assignment

# %%
# %%timeit
pl.at[0,'position'] = "AM"
# Out:
# 11.3 µs ± 1.9 µs per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
pl.head(2)
# Out:
#              name     club  age position  position_cat  market_value  \
# 0  Alexis Sanchez  Arsenal   28       AM             1          65.0
# 1      Mesut Ozil  Arsenal   28       AM             1          50.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region nationality  new_foreign  \
# 0        4329       12.0  17.10%         264       3       Chile            0
# 1        4395        9.5   5.60%         167       2     Germany            0
#
#    age_cat  club_id  big_club  new_signing     popularity
# 0        4        1         1            0  super popular
# 1        4        1         1            0  super popular

# %%
# %%timeit
pl.iat[0,3] = "LW"
# Out:
# 34.5 µs ± 1.31 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
pl.head(2)
# Out:
#              name     club  age position  position_cat  market_value  \
# 0  Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1      Mesut Ozil  Arsenal   28       AM             1          50.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region nationality  new_foreign  \
# 0        4329       12.0  17.10%         264       3       Chile            0
# 1        4395        9.5   5.60%         167       2     Germany            0
#
#    age_cat  club_id  big_club  new_signing     popularity
# 0        4        1         1            0  super popular
# 1        4        1         1            0  super popular

# %% [markdown]
# ### The SettingWithCopy Warning

# %%
pl.head(2)
# Out:
#              name     club  age position  position_cat  market_value  \
# 0  Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1      Mesut Ozil  Arsenal   28       AM             1          50.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region nationality  new_foreign  \
# 0        4329       12.0  17.10%         264       3       Chile            0
# 1        4395        9.5   5.60%         167       2     Germany            0
#
#    age_cat  club_id  big_club  new_signing     popularity
# 0        4        1         1            0  super popular
# 1        4        1         1            0  super popular

# %%
# pandas is warning that it cannot guarantee us that it took place but we can confirm whether it did
pl['page_views'][1] = 3001
# Out:
# <ipython-input-227-87d850dfae27>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pl['page_views'][1] = 3001

# %%
pl.head(2)
# Out:
#              name     club  age position  position_cat  market_value  \
# 0  Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1      Mesut Ozil  Arsenal   28       AM             1          50.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region nationality  new_foreign  \
# 0        4329       12.0  17.10%         264       3       Chile            0
# 1        3001        9.5   5.60%         167       2     Germany            0
#
#    age_cat  club_id  big_club  new_signing     popularity
# 0        4        1         1            0  super popular
# 1        4        1         1            0  super popular

# %%
# it is just copy not view
pl.drop_duplicates()['page_views'][1] = 3000
# Out:
# C:\Users\mdsoh\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3437: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
pl.head(2)
# Out:
#              name     club  age position  position_cat  market_value  \
# 0  Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1      Mesut Ozil  Arsenal   28       AM             1          50.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region nationality  new_foreign  \
# 0        4329       12.0  17.10%         264       3       Chile            0
# 1        3001        9.5   5.60%         167       2     Germany            0
#
#    age_cat  club_id  big_club  new_signing     popularity
# 0        4        1         1            0  super popular
# 1        4        1         1            0  super popular

# %% [markdown]
# ####  To set mode warning

# %%
# Can not show warning slide
pd.options.mode.chained_assignment = None

# %%
pl['club'][0] = 'arsenal'

# %% [markdown]
# ### View vs Copy
#
#        View: it is like a window into the underlying data. it like an opeing that  gives us direct access to the data what we see is what is really in a dataframe. if we modify what we see we end up modifying the data frame.
#
#        Copy: a copy is a replica. if you change the copy we do not affect the underlying dataframe
#
#        2 points rule:
#            1.pandas loves to gives us copies, but
#            2.if we use loc/iloc/at/iat, we are guranteed to get a view

# %%
# View
pl.loc[0:3,'position'] = ['CM','LM',"AM",'BF']

# %%
pl.head(2)
# Out:
#              name     club  age position  position_cat  market_value  \
# 0  Alexis Sanchez  arsenal   28       CM             1          65.0
# 1      Mesut Ozil  Arsenal   28       LM             1          50.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region nationality  new_foreign  \
# 0        4329       12.0  17.10%         264       3       Chile            0
# 1        3001        9.5   5.60%         167       2     Germany            0
#
#    age_cat  club_id  big_club  new_signing     popularity
# 0        4        1         1            0  super popular
# 1        4        1         1            0  super popular

# %%
pl.loc[pl.name.str.startswith('Alexis')]
# Out:
#              name     club  age position  position_cat  market_value  \
# 0  Alexis Sanchez  arsenal   28       CM             1          65.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region nationality  new_foreign  \
# 0        4329       12.0  17.10%         264       3       Chile            0
#
#    age_cat  club_id  big_club  new_signing     popularity
# 0        4        1         1            0  super popular

# %%
pl.loc[pl.name.str.startswith('Petr'),'name'] = "Herry"

# %%
pl.head(2)
# Out:
#              name     club  age position  position_cat  market_value  \
# 0  Alexis Sanchez  arsenal   28       CM             1          65.0
# 1      Mesut Ozil  Arsenal   28       LM             1          50.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region nationality  new_foreign  \
# 0        4329       12.0  17.10%         264       3       Chile            0
# 1        3001        9.5   5.60%         167       2     Germany            0
#
#    age_cat  club_id  big_club  new_signing     popularity
# 0        4        1         1            0  super popular
# 1        4        1         1            0  super popular

# %%
# do not do this
pl['age'].iloc[2] = 30

# %%
pl.head(2)
# Out:
#              name     club  age position  position_cat  market_value  \
# 0  Alexis Sanchez  arsenal   28       CM             1          65.0
# 1      Mesut Ozil  Arsenal   28       LM             1          50.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region nationality  new_foreign  \
# 0        4329       12.0  17.10%         264       3       Chile            0
# 1        3001        9.5   5.60%         167       2     Germany            0
#
#    age_cat  club_id  big_club  new_signing     popularity
# 0        4        1         1            0  super popular
# 1        4        1         1            0  super popular

# %% [markdown]
# ### Adding Columns into Dataframe

# %%
pl.popularity
# Out:
# 0           super popular
# 1           super popular
# 2                 popular
# 3           super popular
# 4                 popular
#               ...
# 460       kind of popular
# 461    relatively unknown
# 462    relatively unknown
# 463       kind of popular
# 464       kind of popular
# Name: popularity, Length: 465, dtype: object

# %%
# First approach adding column name
pl['Column_name'] =.02

# %%
pl.head(3)
# Out:
#              name     club  age position  position_cat  market_value  \
# 0  Alexis Sanchez  arsenal   28       CM             1          65.0
# 1      Mesut Ozil  Arsenal   28       LM             1          50.0
# 2           Herry  Arsenal   30       AM             4           7.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# 1        3001        9.5   5.60%         167       2         Germany
# 2        1529        5.5   5.90%         134       2  Czech Republic
#
#    new_foreign  age_cat  club_id  big_club  new_signing     popularity  \
# 0            0        4        1         1            0  super popular
# 1            0        4        1         1            0  super popular
# 2            0        6        1         1            0        popular
#
#    Column_name
# 0         0.02
# 1         0.02
# 2         0.02

# %%
# Second Approach
# this method gives us adding coulmns where we want to set position
pl.insert(0,'Nick_Name', 'Ozil')

# %%
pl.head(2)
# Out:
#   Nick_Name            name     club  age position  position_cat  \
# 0      Ozil  Alexis Sanchez  arsenal   28       CM             1
# 1      Ozil      Mesut Ozil  Arsenal   28       LM             1
#
#    market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 0          65.0        4329       12.0  17.10%         264       3
# 1          50.0        3001        9.5   5.60%         167       2
#
#   nationality  new_foreign  age_cat  club_id  big_club  new_signing  \
# 0       Chile            0        4        1         1            0
# 1     Germany            0        4        1         1            0
#
#       popularity  Column_name
# 0  super popular         0.02
# 1  super popular         0.02

# %%
# Third Approach
# this method gives us adding multiple coulmns same times
pl.assign(last_name='Ozil',tr=499)
# Out:
#     Nick_Name                 name      club  age position  position_cat  \
# 0        Ozil       Alexis Sanchez   arsenal   28       CM             1
# 1        Ozil           Mesut Ozil   Arsenal   28       LM             1
# 2        Ozil                Herry   Arsenal   30       AM             4
# 3        Ozil         Theo Walcott   Arsenal   28       BF             1
# 4        Ozil    Laurent Koscielny   Arsenal   31       CB             3
# ..        ...                  ...       ...  ...      ...           ...
# 460      Ozil  Edimilson Fernandes  West+Ham   21       CM             2
# 461      Ozil       Arthur Masuaku  West+Ham   23       LB             3
# 462      Ozil            Sam Byram  West+Ham   23       RB             3
# 463      Ozil      Ashley Fletcher  West+Ham   21       CF             1
# 464      Ozil         Diafra Sakho  West+Ham   27       CF             1
#
#      market_value  page_views  fpl_value fpl_sel  ...     nationality  \
# ...

# %% [markdown]
# ### Adding Rows into DataFrame

# %%
mini_df = pl.iloc[:3,:2]

# %%
mini_df
# Out:
#   Nick_Name            name
# 0      Ozil  Alexis Sanchez
# 1      Ozil      Mesut Ozil
# 2      Ozil           Herry

# %%
lieo = pd.Series({'Nick_Name': 'Ok','name':'L'},name=4)

# %%
lieo
# Out:
# Nick_Name    Ok
# name          L
# Name: 4, dtype: object

# %%
mini_df.append(lieo)
# Out:
#   Nick_Name            name
# 0      Ozil  Alexis Sanchez
# 1      Ozil      Mesut Ozil
# 2      Ozil           Herry
# 4        Ok               L

# %%
# Multiple Rows Adding
mp = pd.DataFrame({
    'Nick_Name': ['a','b'],
    'name':['c','d']
},index=[5,6])

# %%
mp
# Out:
#   Nick_Name name
# 5         a    c
# 6         b    d

# %%
# Multiple Rows Adding
mini_df.append(mp)
# Out:
#   Nick_Name            name
# 0      Ozil  Alexis Sanchez
# 1      Ozil      Mesut Ozil
# 2      Ozil           Herry
# 5         a               c
# 6         b               d

# %%
mini_df.loc[7] = ['g','h']

# %%
mini_df
# Out:
#   Nick_Name            name
# 0      Ozil  Alexis Sanchez
# 1      Ozil      Mesut Ozil
# 2      Ozil           Herry
# 7         g               h

# %% [markdown]
# #### How are dataframe stored in memory?
#
#     Memory layout: float, int, object
#
#     ***When adding column, pandas is determain is types, it is float, int, object, then identified block should be added to based on that knowledge, then it modified that block only the rest remain largely untouched unchanged
#     *** When adding rows, we have to touch each and every block,all of them need to be copied modified and reassigned back to memory.==> it is slower , if you adding rows by rows way

# %% [markdown]
# ## Skill Chellenge

# %% [markdown]
# #### From the players dataframe select 4 columns and 4 rows, of no particular order, Assign the resulting 4*4 dataframe to df_random

# %%
df_random = pl.iloc[:4,1:5]

# %%
df_random
# Out:
#              name     club  age position
# 0  Alexis Sanchez  arsenal   28       CM
# 1      Mesut Ozil  Arsenal   28       LM
# 2           Herry  Arsenal   30       AM
# 3    Theo Walcott  Arsenal   28       BF

# %%
df_random1 = pl.sample(4).sample(4,axis=1)

# %%
df_random1
# Out:
#                   name  fpl_points  Column_name  position_cat
# 296        Jesus Gamez           0         0.02             3
# 459     Pablo Zabaleta          45         0.02             3
# 25   Emiliano Martinez           8         0.02             4
# 52          Max Gradel           8         0.02             1

# %% [markdown]
# ##### Etend df_random 1. vertically by adding a new row and 2. horizontally by assing new column. Do this as two seperate operators

# %%
ar = pd.Series({
    'name':'a',
    'club':'Manc',
    'age':23,
    'position':'cb'
},name=5)

# %%
ar
# Out:
# name           a
# club        Manc
# age           23
# position      cb
# Name: 5, dtype: object

# %%
# %%timeit
df_random.append(ar)
# Out:
# 3.49 ms ± 586 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
nn = ['a','b','c','d']

# %%
# %%timeit
df_random.assign(int_n_p=nn)
# Out:
# 559 µs ± 58.1 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# Milisecond to Microsecond
3.95 * 1000
# Out:
# 3950.0

# %%
# Adding column is faster than adding Rows
3950 / 505
# Out:
# 7.821782178217822
